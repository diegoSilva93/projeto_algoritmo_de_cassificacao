# %%
#Download bibliotecas
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
#carregamento do dataset

dataset = pd.read_csv("Churn_Modelling.csv.csv")

# %%
#Fazendo análise exploratória dos dados
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
# Selecionando variáveis para X

X = dataset.iloc[:, 3:13].values

# %%
# Selecionand variavel dependente Y
Y = dataset.iloc[:, 13].values

# %%
#Transformando dados categóricos em numéricos
label_encoder_X1 = LabelEncoder()
X[:,1] = label_encoder_X1.fit_transform(X[:,1])

label_encoder_X2 = LabelEncoder()
X[:,2] = label_encoder_X1.fit_transform(X[:,2])

# %%
one_hot_encoder = make_column_transformer((OneHotEncoder(categories = "auto", sparse = False), [1]), remainder = "passthrough")

# %%
X = one_hot_encoder.fit_transform(X)
X = X[:,1:]

# %%
# Treino e teste
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
classifier = Sequential()
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
classifier.fit(X_train, Y_train, batch_size = 10, epochs = 100)

Y_pred = classifier.predict(X_test)
Y_pred = (Y_pred > 0.5)

cm = confusion_matrix(Y_test, Y_pred)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 2s 1ms/step - loss: 0.4895 - accuracy: 0.7960
# Epoch 2/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4273 - accuracy: 0.7960
# Epoch 3/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4225 - accuracy: 0.7960
# Epoch 4/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4189 - accuracy: 0.8199
# Epoch 5/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4169 - accuracy: 0.8266
# Epoch 6/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4147 - accuracy: 0.8289
# Epoch 7/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4132 - accuracy: 0.8311
# Epoch 8/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4121 - accuracy: 0.8322
# Epoch 9/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4107 - accuracy: 0.8329
# Epoch 10/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4096 - accuracy: 0.8330
# Epoch 11/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4090 - accuracy: 0.8319
# Epoch 12/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4083 - accuracy: 0.8322
# Epoch 13/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4075 - accuracy: 0.8339
# Epoch 14/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4073 - accuracy: 0.8332
# Epoch 15/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4062 - accuracy: 0.8346
# Epoch 16/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4059 - accuracy: 0.8345
# Epoch 17/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4054 - accuracy: 0.8334
# Epoch 18/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4054 - accuracy: 0.8332
# Epoch 19/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4050 - accuracy: 0.8351
# Epoch 20/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4048 - accuracy: 0.8336
# Epoch 21/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4043 - accuracy: 0.8344
# Epoch 22/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4037 - accuracy: 0.8342
# Epoch 23/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4040 - accuracy: 0.8339
# Epoch 24/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4039 - accuracy: 0.8339
# Epoch 25/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4029 - accuracy: 0.8328
# Epoch 26/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4036 - accuracy: 0.8340
# Epoch 27/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4034 - accuracy: 0.8347
# Epoch 28/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4027 - accuracy: 0.8347
# Epoch 29/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4031 - accuracy: 0.8346
# Epoch 30/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4031 - accuracy: 0.8328
# Epoch 31/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4029 - accuracy: 0.8342
# Epoch 32/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4029 - accuracy: 0.8356
# Epoch 33/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4026 - accuracy: 0.8338
# Epoch 34/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4025 - accuracy: 0.8344
# Epoch 35/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4025 - accuracy: 0.8341
# Epoch 36/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4022 - accuracy: 0.8345
# Epoch 37/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4030 - accuracy: 0.8342
# Epoch 38/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4022 - accuracy: 0.8330
# Epoch 39/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4020 - accuracy: 0.8338
# Epoch 40/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4024 - accuracy: 0.8331
# Epoch 41/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4020 - accuracy: 0.8339
# Epoch 42/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4022 - accuracy: 0.8329
# Epoch 43/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4017 - accuracy: 0.8338
# Epoch 44/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4022 - accuracy: 0.8353
# Epoch 45/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4018 - accuracy: 0.8359
# Epoch 46/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4020 - accuracy: 0.8336
# Epoch 47/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4023 - accuracy: 0.8350
# Epoch 48/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4010 - accuracy: 0.8331
# Epoch 49/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4023 - accuracy: 0.8354
# Epoch 50/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4015 - accuracy: 0.8351
# Epoch 51/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4017 - accuracy: 0.8338
# Epoch 52/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4013 - accuracy: 0.8349
# Epoch 53/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4014 - accuracy: 0.8340
# Epoch 54/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4013 - accuracy: 0.8338
# Epoch 55/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4018 - accuracy: 0.8339
# Epoch 56/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4015 - accuracy: 0.8356
# Epoch 57/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4012 - accuracy: 0.8344
# Epoch 58/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4009 - accuracy: 0.8342
# Epoch 59/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4010 - accuracy: 0.8344
# Epoch 60/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4013 - accuracy: 0.8335
# Epoch 61/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4011 - accuracy: 0.8347
# Epoch 62/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4008 - accuracy: 0.8346
# Epoch 63/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4015 - accuracy: 0.8341
# Epoch 64/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4013 - accuracy: 0.8340
# Epoch 65/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4012 - accuracy: 0.8345
# Epoch 66/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4011 - accuracy: 0.8336
# Epoch 67/100
# 800/800 [==============================] - 1s 955us/step - loss: 0.4012 - accuracy: 0.8363
# Epoch 68/100
# 800/800 [==============================] - 1s 968us/step - loss: 0.4008 - accuracy: 0.8336
# Epoch 69/100
# 800/800 [==============================] - 1s 980us/step - loss: 0.4014 - accuracy: 0.8361
# Epoch 70/100
# 800/800 [==============================] - 1s 984us/step - loss: 0.4010 - accuracy: 0.8349
# Epoch 71/100
# 800/800 [==============================] - 1s 968us/step - loss: 0.4012 - accuracy: 0.8357
# Epoch 72/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4010 - accuracy: 0.8357
# Epoch 73/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4010 - accuracy: 0.8338
# Epoch 74/100
# 800/800 [==============================] - 1s 988us/step - loss: 0.4011 - accuracy: 0.8350
# Epoch 75/100
# 800/800 [==============================] - 1s 962us/step - loss: 0.4009 - accuracy: 0.8341
# Epoch 76/100
# 800/800 [==============================] - 1s 987us/step - loss: 0.4010 - accuracy: 0.8336
# Epoch 77/100
# 800/800 [==============================] - 1s 955us/step - loss: 0.4011 - accuracy: 0.8354
# Epoch 78/100
# 800/800 [==============================] - 1s 987us/step - loss: 0.4007 - accuracy: 0.8354
# Epoch 79/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4009 - accuracy: 0.8350
# Epoch 80/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4007 - accuracy: 0.8349
# Epoch 81/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4011 - accuracy: 0.8345
# Epoch 82/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4008 - accuracy: 0.8334
# Epoch 83/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4004 - accuracy: 0.8341
# Epoch 84/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4009 - accuracy: 0.8345
# Epoch 85/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4010 - accuracy: 0.8350
# Epoch 86/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4006 - accuracy: 0.8346
# Epoch 87/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4008 - accuracy: 0.8353
# Epoch 88/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4014 - accuracy: 0.8334
# Epoch 89/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4004 - accuracy: 0.8342
# Epoch 90/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4006 - accuracy: 0.8359
# Epoch 91/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4008 - accuracy: 0.8332
# Epoch 92/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4008 - accuracy: 0.8347
# Epoch 93/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4009 - accuracy: 0.8355
# Epoch 94/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4006 - accuracy: 0.8360
# Epoch 95/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4005 - accuracy: 0.8357
# Epoch 96/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4008 - accuracy: 0.8340
# Epoch 97/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4005 - accuracy: 0.8339
# Epoch 98/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4006 - accuracy: 0.8366
# Epoch 99/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4004 - accuracy: 0.8351
# Epoch 100/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4008 - accuracy: 0.8351
# 63/63 [==============================] - 0s 1ms/step

# %%
print(cm)
# Out:
# [[1546   49]
#  [ 265  140]]

# %%
acuracia = accuracy_score(Y_test,Y_pred)

# %%
print(acuracia)
# Out:
# 0.843

# %%
#Isso significa que o modelo tem uma acurácia de 84.30%, considerado satisfatório para um modelo de classificação
